# %%
import odds, arb
import json
api_key = 'acb9ca2b9b8fc48935534934b731019c'
va_bookmakers = 'barstool,betmgm,betrivers,draftkings,fanduel,pointsbetus,unibet_us,williamhill_us,wynnbet'
my_bookmakers = 'barstool,draftkings,fanduel'

import importlib

# %%
importlib.reload(arb)
# Out:
# <module 'arb' from '/home/wloving77/projects_outside_school/Githubs/mitch_arb/sportsbook-arb/arb.py'>

# %%
games_h2h = odds.get_mlb_h2h_odds(api_key, va_bookmakers)
games_spreads = odds.get_mlb_spreads_odds(api_key, va_bookmakers)
games_totals = odds.get_mlb_totals_odds(api_key, va_bookmakers)

# %%
arb.totals_arb(games_totals, -.05)
# Out:
# Return Threshold is: -0.05
# Books for (San Diego Padres, Los Angeles Dodgers)
#
# 	Total: 9.0:
# 		    draftkings: 1.82, San Diego Padres, 1.11*b_2
# 		    draftkings: 2.02, Los Angeles Dodgers, 0.901*b_1
# 		    Return: -4.26%
#
# 		    fanduel: 1.85, San Diego Padres, 1.059*b_2
# 		    fanduel: 1.96, Los Angeles Dodgers, 0.944*b_1
# 		    Return: -4.829%
#
# 		    pointsbetus: 1.83, San Diego Padres, 1.093*b_2
# 		    pointsbetus: 2.0, Los Angeles Dodgers, 0.915*b_1
# 		    Return: -4.439%
#
# 	Total: 9.5:
# 		    williamhill_us: 2.0, San Diego Padres, 0.915*b_2
# 		    williamhill_us: 1.83, Los Angeles Dodgers, 1.093*b_1
# 		    Return: -4.439%
#
# 		    barstool: 2.05, San Diego Padres, 0.878*b_2
# 		    barstool: 1.8, Los Angeles Dodgers, 1.139*b_1
# 		    Return: -4.156%
#
# 		    wynnbet: 2.0, San Diego Padres, 0.915*b_2
# 		    wynnbet: 1.83, Los Angeles Dodgers, 1.093*b_1
# 		    Return: -4.439%
#
# 		    betmgm: 2.0, San Diego Padres, 0.915*b_2
# ...
